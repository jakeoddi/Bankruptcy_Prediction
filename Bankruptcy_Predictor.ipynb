# %% [markdown]
# # Overview

# %% [markdown]
# This project analyzes business fundamental data of many companies during one year of operation in order to predict which of those companies later on went bankrupt. An ensemble model is created out of logistic regression and random forest models in order to perform these predictions. As a product of the project, a model is produced that financial groups could use in order to assess risk of investment in a given company, based on whether or not it was predicted that company would go bankrupt.

# %% [markdown]
# # Business Problem

# %% [markdown]
# As much of corporate financial investment revolves around the accurate prediction of a company's performance, any sort of tool used to assess a company's future state is incredibly useful. As such, the data science team set out to create a tool that would predict an extreme case in a company's future, its bankrupty. With dependable information about a company's impending bankruptcy, investors could either know to avoid bullish positions or to, conversely, take bearish positions in that company. What is more, with dependable bankruptcy forecasting, financial institutions could better evaluate and target the future acquisition of certain companies, if it were desired to do so after those companies' bankruptcies. Lastly, by creating a dependable model, the team can determine which financial indicators are most influential in determining whether or not a company will go bankrupt.

# %% [markdown]
# # Data Understanding

# %% [markdown]
# To achieve analysis, the team uses data on Polish companies operating between 2007 and 2013. This data was obtained via the University of California at Irvine's machine learning repository. Its ultimate source is the Emerging Markets Information Service.
#
# The team uses data on only one year of operation (2010), as it had the highest number of data points (10,503 instances) and companies surveyed. For each company in this set, financial fundamental numbers are listed (e.g. debts-to-assets ratio, EBITDA, etc.), as well as a variable that indicates whether or not that company went bankrupt three years later. As ulitimate bankruptcy is the target variable for this analysis, the model fit to this data then will effectively predict if a company, based on its financial fundamentals, will go bankrupt in three years.

# %% [markdown]
# # Data Preparation, Exploratory Data Analysis (EDA), and Feature Engineering

# %% [markdown]
# Data is first imported from its .csv file as a dataframe.

# %%
# Import relevant packages

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import confusion_matrix
try:
    from sklearn.preprocessing import OrdinalEncoder
    from sklearn.preprocessing import OneHotEncoder
except ImportError:
    from future_encoders import OneHotEncoder
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
    
# Import data set as a dataframe

df=pd.read_csv('data/csv_result-3year.csv')

# %% [markdown]
# Data is then cleaned in order to eliminate all null or missing values and format as number variables in order to be more easily manipulated. Rows with missing values were simply removed, as there were enough data points to still perform analysis without having to impute those missing values. Dataframe columns were then renamed for readability's sake.

# %%
# Rows with null values are removed from the dataset 

df.dropna(inplace=True)

# Rows with '?' as values were removed from the dataset

for col in list(df.columns):
    df=df[df[col]!='?']

# Format all dataframe values as numbers
    
df=df.apply(pd.to_numeric)

# Rename columns for readibility

df.rename(columns = {'Attr1': 'return_on_assets',
                     'Attr2': 'debt_to_assets', 
                     'Attr3': 'working_capital_to_assets',
                     'Attr4': 'current_ratio',
                     'Attr5': '[(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365',
                     'Attr6': 'retained_earnings_to_assets',
                     'Attr7': 'EBIT_to_assets',
                     'Attr8': 'book_value_equity_to_assets',
                     'Attr9': 'asset_turnover',
                     'Attr10': 'equity_to_assets',
                     'Attr11': '(gross profit + extraordinary items + financial expenses) / total assets',
                     'Attr12': 'gross_profit_to_current_debt',
                     'Attr13': '(gross profit + depreciation) / sales',
                     'Attr14': '(gross profit + interest) / total assets',
                     'Attr15': '(total liabilities * 365) / (gross profit + depreciation)',
                     'Attr16': '(gross profit + depreciation) / total liabilities',
                     'Attr17': 'asset_to_debt',
                     'Attr18': 'gross_profitability',
                     'Attr19': 'gross_profit_margin',
                     'Attr20': 'days_sales_in_inventory',
                     'Attr21': 'y/y_sales',
                     'Atrr22': 'operating_roa',
                     'Attr23': 'net_profit_ratio',
                     'Attr24': '3_yr_gross_profitability',
                     'Attr25': '(equity - share capital) / total assets',
                     'Attr26': '(net profit + depreciation) / total liabilities',
                     'Attr27': 'operating_margin',
                     'Attr28': 'working_capital_to_fixed_assets',
                     'Attr29': 'log_assets',
                     'Attr30': 'net_debt_to_sales',
                     'Attr31': 'EBT_to_sales', # check
                     'Attr32': 'average_payment_period',
                     'Attr33': 'operating_costs_to_current_debt',
                     'Attr34': 'operating_costs_to_total_debt',
                     'Attr35': 'net_asset_turnover',
                     'Attr36': 'total sales / total assets',
                     'Attr37': 'long_term_quick_ratio',
                     'Attr38': 'constant_capital_to_total_assets',
                     'Attr39': 'net_profit_margin',
                     'Attr40': '(current assets - inventory - receivables) / short-term liabilities',
                     'Attr41': 'months_debt_to_profit',
                     'Attr42': 'EBITDA_sales',
                     'Attr43': 'rotation_receivables_plus_inventory_turnover',
                     'Attr44': 'days_receivables_to_sales',
                     'Attr45': 'net_inventory_turnover',
                     'Attr46': 'short_term_quick_ratio',
                     'Attr47': 'days_inventory_to_cogs',
                     'Attr48': 'EBITDA_rota',
                     'Attr49': 'EBITDA_margin',
                     'Attr50': 'current_assets_to_total_debt',
                     'Attr51': 'current_debt_to_total_assets',
                     'Attr52': 'days_debt_to_cogs',
                     'Attr53': 'equity_to_fixed_assets',
                     'Attr54': 'constant_capital_to_fixed_assets',
                     'Attr55': 'working_capital',
                     'Attr56': 'contribution_margin', 
                     'Attr57': 'total costs /total sales',
                     'Attr58': 'operating_ratio',
                     'Attr59': 'long_term_debt_to_equity',
                     'Attr60': 'inventory_turnover',
                     'Attr61': 'receivables_turnover',
                     'Attr62': 'days_short_term_debt_to_sales',
                     'Attr63': 'sales_to_short_term_debt',
                     'Attr64': 'fixed_asset_turnover'
                    }, inplace=True)

# %% [markdown]
# Next, all data is graphed against an arbitrary independent variable in order to just visually inspect the distribution of data to find anomalies or outliers of any feature. X labels on graphs are omitted, as they are arbitrary and the graphs are more readable without them.

# %%
# Define arbitrary x variable as the length of the data set

x=list(range(0,len(df.id)))

# Initiate subpot figure with a plot for each examined feature

figure, ax = plt.subplots(13, 5, figsize=(50, 50))
cols= list(df.columns)
cols.pop(0)
major=list(range(0, 13))
minor=list(range(0, 5))

# Name and label each graph, and plot data

for row in major:
    for col in minor:
        index=(row)*5+col
        ax[row][col].set_title(cols[index])
        ax[row][col].set_ylabel('Magnitude')
        ax[row][col].scatter(x, list(df[cols[index]]))

# %% [markdown]
# Looking at each graph, it appears that here and there, each feature has a handful of values that are far greater than the rest of the set. However, because the proportion of these points is incredibly small when compared to the overall number of data points in the set, the data science team elects to keep the data points as are for the analysis. If overall evaluation metrics for the set's model are not sufficient, the data team will keep in mind that maybe the first step to improving the model would be to remove some of these outliers.
#
# Next, the data team graphs each feature of the set against the target variable to get an initial sense of where strong correlations lie between the set's features and whether or not the company later on went bankrupt. X labels on graphs are omitted, as they are arbitrary and the graphs are more readable without them.

# %%
# Define arbitrary x variable as the length of the data set

x=list(range(0,len(df.id)))

# Initiate subpot figure with a plot for each examined feature

figure, ax = plt.subplots(13, 5, figsize=(50, 50))
cols= list(df.columns)
cols.pop(0)
major=list(range(0, 13))
minor=list(range(0, 5))

# Name and label each graph, and plot data

for row in major:
    for col in minor:
        index=(row)*5+col
        ax[row][col].set_title(cols[index])
        ax[row][col].set_ylabel('Magnitude')
        ax[row][col].scatter(df['class'], list(df[cols[index]]))
        ax[row][col].set_xticks([0, 1])

# %% [markdown]
# A correlation matrix for the entire dataframe is produced to supplement the graphs of features against the target above. With both of these bits of information, the data science team can identify features that will likely be most important for development of the model. In general, tight groupings of positive bankrupt data points in the graphs above indicate higher influence of the feature on the target. This influence can then be corroborated by high values on the correlation matrix below.

# %%
# Make all rows and columns of correlation matrix visible
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Create correlation matrix, and sequence according to greatest correlation absolute value
corrs=df.corr()
corrs=corrs.apply(lambda x: abs(x))
corrs.sort_values(by=['class'], ascending=False)
# Out:
#                                                           id  \
# class                                               0.248492
# id                                                  1.000000
# (equity - share capital) / total assets             0.067859
# current_debt_to_total_assets                        0.070053
# (total liabilities * 365) / (gross profit + dep...  0.035021
# debt_to_assets                                      0.058529
# retained_earnings_to_assets                         0.065511
# net_asset_turnover                                  0.020531
# constant_capital_to_total_assets                    0.053806
# asset_turnover                                      0.089307
# (gross profit + depreciation) / total liabilities   0.040193
# (net profit + depreciation) / total liabilities     0.036943
# equity_to_assets                                    0.047436
# (gross profit + interest) / total assets            0.015556
# EBIT_to_assets                                      0.015468
# return_on_assets                                    0.009473
# Attr22                                              0.005251
# working_capital_to_assets                           0.090873
# asset_to_debt                                       0.061304
# book_value_equity_to_assets                         0.060273
# (gross profit + extraordinary items + financial...  0.003832
# log_assets                                          0.043598
# current_assets_to_total_debt                        0.065985
# operating_costs_to_total_debt                       0.065492
# 3_yr_gross_profitability                            0.059152
# gross_profit_margin                                 0.004982
# net_profit_margin                                   0.008993
# net_profit_ratio                                    0.009106
# total sales / total assets                          0.140896
# EBT_to_sales                                        0.005218
# sales_to_short_term_debt                            0.033985
# operating_costs_to_current_debt                     0.042974
# EBITDA_rota                                         0.026022
# gross_profit_to_current_debt                        0.001146
# total costs /total sales                            0.002908
# short_term_quick_ratio                              0.021917
# working_capital                                     0.019101
# EBITDA_sales                                        0.003644
# current_ratio                                       0.019293
# gross_profitability                                 0.012079
# receivables_turnover                                0.060735
# (current assets - inventory - receivables) / sh...  0.018163
# EBITDA_margin                                       0.002745
# long_term_quick_ratio                               0.026317
# inventory_turnover                                  0.006973
# days_inventory_to_cogs                              0.010400
# y/y_sales                                           0.014244
# days_debt_to_cogs                                   0.002572
# (gross profit + depreciation) / sales               0.009121
# long_term_debt_to_equity                            0.009307
# [(cash + short-term securities + receivables - ...  0.015334
# operating_margin                                    0.009906
# months_debt_to_profit                               0.001710
# operating_ratio                                     0.008774
# contribution_margin                                 0.008722
# days_sales_in_inventory                             0.005921
# average_payment_period                              0.002511
# rotation_receivables_plus_inventory_turnover        0.002958
# net_inventory_turnover                              0.020189
# days_short_term_debt_to_sales                       0.002484
# days_receivables_to_sales                           0.000992
# working_capital_to_fixed_assets                     0.020114
# constant_capital_to_fixed_assets                    0.020308
# fixed_asset_turnover                                0.015933
# equity_to_fixed_assets                              0.020112
# net_debt_to_sales                                   0.004139
#
#                                                     return_on_assets  \
# class                                                       0.058435
# id                                                          0.009473
# (equity - share capital) / total assets                     0.434729
# current_debt_to_total_assets                                0.301755
# (total liabilities * 365) / (gross profit + dep...          0.002609
# debt_to_assets                                              0.418667
# retained_earnings_to_assets                                 0.387198
# net_asset_turnover                                          0.695242
# constant_capital_to_total_assets                            0.438440
# asset_turnover                                              0.163995
# (gross profit + depreciation) / total liabilities           0.558690
# (net profit + depreciation) / total liabilities             0.560410
# equity_to_assets                                            0.528367
# (gross profit + interest) / total assets                    0.988978
# EBIT_to_assets                                              0.989017
# return_on_assets                                            1.000000
# Attr22                                                      0.824113
# working_capital_to_assets                                   0.352875
# asset_to_debt                                               0.166631
# book_value_equity_to_assets                                 0.185841
# (gross profit + extraordinary items + financial...          0.929900
# log_assets                                                  0.041528
# current_assets_to_total_debt                                0.187508
# operating_costs_to_total_debt                               0.206182
# 3_yr_gross_profitability                                    0.683528
# gross_profit_margin                                         0.446222
# net_profit_margin                                           0.284998
# net_profit_ratio                                            0.438291
# total sales / total assets                                  0.212886
# EBT_to_sales                                                0.444607
# sales_to_short_term_debt                                    0.174946
# operating_costs_to_current_debt                             0.146262
# EBITDA_rota                                                 0.649535
# gross_profit_to_current_debt                                0.234263
# total costs /total sales                                    0.021388
# short_term_quick_ratio                                      0.062138
# working_capital                                             0.083601
# EBITDA_sales                                                0.145847
# current_ratio                                               0.063453
# gross_profitability                                         0.190979
# receivables_turnover                                        0.042457
# (current assets - inventory - receivables) / sh...          0.043286
# EBITDA_margin                                               0.148339
# long_term_quick_ratio                                       0.003636
# inventory_turnover                                          0.009729
# days_inventory_to_cogs                                      0.005711
# y/y_sales                                                   0.015049
# days_debt_to_cogs                                           0.000165
# (gross profit + depreciation) / sales                       0.005536
# long_term_debt_to_equity                                    0.021087
# [(cash + short-term securities + receivables - ...          0.002466
# operating_margin                                            0.023261
# months_debt_to_profit                                       0.011982
# operating_ratio                                             0.004395
# contribution_margin                                         0.004219
# days_sales_in_inventory                                     0.010659
# average_payment_period                                      0.000257
# rotation_receivables_plus_inventory_turnover                0.011641
# net_inventory_turnover                                      0.017958
# days_short_term_debt_to_sales                               0.034234
# days_receivables_to_sales                                   0.012655
# working_capital_to_fixed_assets                             0.029252
# constant_capital_to_fixed_assets                            0.031180
# fixed_asset_turnover                                        0.009089
# equity_to_fixed_assets                                      0.095139
# net_debt_to_sales                                           0.031825
#
#                                                     debt_to_assets  \
# class                                                     0.080942
# id                                                        0.058529
# (equity - share capital) / total assets                   0.816450
# current_debt_to_total_assets                              0.698566
# (total liabilities * 365) / (gross profit + dep...        0.029653
# debt_to_assets                                            1.000000
# retained_earnings_to_assets                               0.518823
# net_asset_turnover                                        0.282629
# constant_capital_to_total_assets                          0.513808
# asset_turnover                                            0.116063
# (gross profit + depreciation) / total liabilities         0.390439
# (net profit + depreciation) / total liabilities           0.378382
# equity_to_assets                                          0.859154
# (gross profit + interest) / total assets                  0.432219
# EBIT_to_assets                                            0.432239
# return_on_assets                                          0.418667
# Attr22                                                    0.295794
# working_capital_to_assets                                 0.595951
# asset_to_debt                                             0.508420
# book_value_equity_to_assets                               0.508322
# (gross profit + extraordinary items + financial...        0.352417
# log_assets                                                0.191074
# current_assets_to_total_debt                              0.436869
# operating_costs_to_total_debt                             0.176473
# 3_yr_gross_profitability                                  0.472349
# gross_profit_margin                                       0.255873
# net_profit_margin                                         0.203246
# net_profit_ratio                                          0.249438
# total sales / total assets                                0.093912
# EBT_to_sales                                              0.259900
# sales_to_short_term_debt                                  0.194406
# operating_costs_to_current_debt                           0.189398
# EBITDA_rota                                               0.234354
# gross_profit_to_current_debt                              0.132123
# total costs /total sales                                  0.019034
# short_term_quick_ratio                                    0.113674
# working_capital                                           0.151439
# EBITDA_sales                                              0.074714
# current_ratio                                             0.124420
# gross_profitability                                       0.083186
# receivables_turnover                                      0.012789
# (current assets - inventory - receivables) / sh...        0.089685
# EBITDA_margin                                             0.081151
# long_term_quick_ratio                                     0.017107
# inventory_turnover                                        0.023807
# days_inventory_to_cogs                                    0.009821
# y/y_sales                                                 0.011949
# days_debt_to_cogs                                         0.017645
# (gross profit + depreciation) / sales                     0.002530
# long_term_debt_to_equity                                  0.030132
# [(cash + short-term securities + receivables - ...        0.006831
# operating_margin                                          0.011431
# months_debt_to_profit                                     0.003778
# operating_ratio                                           0.013172
# contribution_margin                                       0.013227
# days_sales_in_inventory                                   0.015596
# average_payment_period                                    0.018028
# rotation_receivables_plus_inventory_turnover              0.021866
# net_inventory_turnover                                    0.019049
# days_short_term_debt_to_sales                             0.060325
# days_receivables_to_sales                                 0.029568
# working_capital_to_fixed_assets                           0.011632
# constant_capital_to_fixed_assets                          0.014658
# fixed_asset_turnover                                      0.029751
# equity_to_fixed_assets                                    0.142277
# net_debt_to_sales                                         0.060542
#
#                                                     working_capital_to_assets  \
# class                                                                0.054505
# id                                                                   0.090873
# (equity - share capital) / total assets                              0.511208
# current_debt_to_total_assets                                         0.681470
# (total liabilities * 365) / (gross profit + dep...                   0.009379
# debt_to_assets                                                       0.595951
# retained_earnings_to_assets                                          0.319003
# net_asset_turnover                                                   0.287161
# constant_capital_to_total_assets                                     0.545586
# asset_turnover                                                       0.000762
# (gross profit + depreciation) / total liabilities                    0.331433
# (net profit + depreciation) / total liabilities                      0.314778
# equity_to_assets                                                     0.542766
# (gross profit + interest) / total assets                             0.371176
# EBIT_to_assets                                                       0.371232
# return_on_assets                                                     0.352875
# Attr22                                                               0.282867
# working_capital_to_assets                                            1.000000
# asset_to_debt                                                        0.361625
# book_value_equity_to_assets                                          0.369517
# (gross profit + extraordinary items + financial...                   0.330151
# log_assets                                                           0.027230
# current_assets_to_total_debt                                         0.530615
# operating_costs_to_total_debt                                        0.215610
# 3_yr_gross_profitability                                             0.391311
# gross_profit_margin                                                  0.210891
# net_profit_margin                                                    0.158368
# net_profit_ratio                                                     0.201320
# total sales / total assets                                           0.014557
# EBT_to_sales                                                         0.200295
# sales_to_short_term_debt                                             0.250482
# operating_costs_to_current_debt                                      0.245050
# EBITDA_rota                                                          0.235595
# gross_profit_to_current_debt                                         0.147942
# total costs /total sales                                             0.017572
# short_term_quick_ratio                                               0.188723
# working_capital                                                      0.235460
# EBITDA_sales                                                         0.064291
# current_ratio                                                        0.216199
# gross_profitability                                                  0.067402
# receivables_turnover                                                 0.068683
# (current assets - inventory - receivables) / sh...                   0.145264
# EBITDA_margin                                                        0.065976
# long_term_quick_ratio                                                0.014938
# inventory_turnover                                                   0.024081
# days_inventory_to_cogs                                               0.001540
# y/y_sales                                                            0.016482
# days_debt_to_cogs                                                    0.005090
# (gross profit + depreciation) / sales                                0.006253
# long_term_debt_to_equity                                             0.022688
# [(cash + short-term securities + receivables - ...                   0.001459
# operating_margin                                                     0.002692
# months_debt_to_profit                                                0.000836
# operating_ratio                                                      0.001347
# contribution_margin                                                  0.001370
# days_sales_in_inventory                                              0.009492
# average_payment_period                                               0.005476
# rotation_receivables_plus_inventory_turnover                         0.004341
# net_inventory_turnover                                               0.022225
# days_short_term_debt_to_sales                                        0.048359
# days_receivables_to_sales                                            0.002506
# working_capital_to_fixed_assets                                      0.060144
# constant_capital_to_fixed_assets                                     0.061332
# fixed_asset_turnover                                                 0.017464
# equity_to_fixed_assets                                               0.138127
# net_debt_to_sales                                                    0.032695
#
#                                                     current_ratio  \
# class                                                    0.015788
# id                                                       0.019293
# (equity - share capital) / total assets                  0.084125
# current_debt_to_total_assets                             0.157113
# (total liabilities * 365) / (gross profit + dep...       0.004502
# debt_to_assets                                           0.124420
# retained_earnings_to_assets                              0.013914
# net_asset_turnover                                       0.054178
# constant_capital_to_total_assets                         0.124903
# asset_turnover                                           0.027778
# (gross profit + depreciation) / total liabilities        0.203889
# (net profit + depreciation) / total liabilities          0.185074
# equity_to_assets                                         0.112920
# (gross profit + interest) / total assets                 0.070858
# EBIT_to_assets                                           0.070875
# return_on_assets                                         0.063453
# Attr22                                                   0.058940
# working_capital_to_assets                                0.216199
# asset_to_debt                                            0.260950
# book_value_equity_to_assets                              0.267427
# (gross profit + extraordinary items + financial...       0.066505
# log_assets                                               0.055960
# current_assets_to_total_debt                             0.353741
# operating_costs_to_total_debt                            0.103046
# 3_yr_gross_profitability                                 0.135575
# gross_profit_margin                                      0.047905
# net_profit_margin                                        0.038218
# net_profit_ratio                                         0.041638
# total sales / total assets                               0.043037
# EBT_to_sales                                             0.045438
# sales_to_short_term_debt                                 0.781469
# operating_costs_to_current_debt                          0.657786
# EBITDA_rota                                              0.056557
# gross_profit_to_current_debt                             0.892694
# total costs /total sales                                 0.003400
# short_term_quick_ratio                                   0.976640
# working_capital                                          0.035855
# EBITDA_sales                                             0.014930
# current_ratio                                            1.000000
# gross_profitability                                      0.012153
# receivables_turnover                                     0.004501
# (current assets - inventory - receivables) / sh...       0.953863
# EBITDA_margin                                            0.017074
# long_term_quick_ratio                                    0.000046
# inventory_turnover                                       0.004489
# days_inventory_to_cogs                                   0.001054
# y/y_sales                                                0.003301
# days_debt_to_cogs                                        0.003139
# (gross profit + depreciation) / sales                    0.001908
# long_term_debt_to_equity                                 0.003874
# [(cash + short-term securities + receivables - ...       0.001407
# operating_margin                                         0.003879
# months_debt_to_profit                                    0.001375
# operating_ratio                                          0.001429
# contribution_margin                                      0.001419
# days_sales_in_inventory                                  0.000897
# average_payment_period                                   0.003165
# rotation_receivables_plus_inventory_turnover             0.000144
# net_inventory_turnover                                   0.003638
# days_short_term_debt_to_sales                            0.009183
# days_receivables_to_sales                                0.000846
# working_capital_to_fixed_assets                          0.080811
# constant_capital_to_fixed_assets                         0.082139
# fixed_asset_turnover                                     0.007878
# equity_to_fixed_assets                                   0.168685
# net_debt_to_sales                                        0.007790
#
#                                                     [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365  \
# class                                                                                        0.002236
# id                                                                                           0.015334
# (equity - share capital) / total assets                                                      0.002684
# current_debt_to_total_assets                                                                 0.015058
# (total liabilities * 365) / (gross profit + dep...                                           0.001648
# debt_to_assets                                                                               0.006831
# retained_earnings_to_assets                                                                  0.001133
# net_asset_turnover                                                                           0.003947
# constant_capital_to_total_assets                                                             0.009721
# asset_turnover                                                                               0.014442
# (gross profit + depreciation) / total liabilities                                            0.006943
# (net profit + depreciation) / total liabilities                                              0.006749
# equity_to_assets                                                                             0.005421
# (gross profit + interest) / total assets                                                     0.002955
# EBIT_to_assets                                                                               0.002953
# return_on_assets                                                                             0.002466
# Attr22                                                                                       0.004311
# working_capital_to_assets                                                                    0.001459
# asset_to_debt                                                                                0.007087
# book_value_equity_to_assets                                                                  0.007004
# (gross profit + extraordinary items + financial...                                           0.003307
# log_assets                                                                                   0.002972
# current_assets_to_total_debt                                                                 0.002106
# operating_costs_to_total_debt                                                                0.005708
# 3_yr_gross_profitability                                                                     0.000839
# gross_profit_margin                                                                          0.000585
# net_profit_margin                                                                            0.001382
# net_profit_ratio                                                                             0.000346
# total sales / total assets                                                                   0.008254
# EBT_to_sales                                                                                 0.000483
# sales_to_short_term_debt                                                                     0.003165
# operating_costs_to_current_debt                                                              0.002873
# EBITDA_rota                                                                                  0.000111
# gross_profit_to_current_debt                                                                 0.001863
# total costs /total sales                                                                     0.000167
# short_term_quick_ratio                                                                       0.002217
# working_capital                                                                              0.001856
# EBITDA_sales                                                                                 0.000798
# current_ratio                                                                                0.001407
# gross_profitability                                                                          0.000801
# receivables_turnover                                                                         0.005292
# (current assets - inventory - receivables) / sh...                                           0.001385
# EBITDA_margin                                                                                0.000777
# long_term_quick_ratio                                                                        0.000673
# inventory_turnover                                                                           0.000518
# days_inventory_to_cogs                                                                       0.001051
# y/y_sales                                                                                    0.000225
# days_debt_to_cogs                                                                            0.000506
# (gross profit + depreciation) / sales                                                        0.000229
# long_term_debt_to_equity                                                                     0.000322
# [(cash + short-term securities + receivables - ...                                           1.000000
# operating_margin                                                                             0.000240
# months_debt_to_profit                                                                        0.000219
# operating_ratio                                                                              0.000280
# contribution_margin                                                                          0.000278
# days_sales_in_inventory                                                                      0.000109
# average_payment_period                                                                       0.000507
# rotation_receivables_plus_inventory_turnover                                                 0.000477
# net_inventory_turnover                                                                       0.000142
# days_short_term_debt_to_sales                                                                0.000735
# days_receivables_to_sales                                                                    0.000947
# working_capital_to_fixed_assets                                                              0.000333
# constant_capital_to_fixed_assets                                                             0.000276
# fixed_asset_turnover                                                                         0.000091
# equity_to_fixed_assets                                                                       0.000067
# net_debt_to_sales                                                                            0.000813
#
#                                                     retained_earnings_to_assets  \
# class                                                                  0.080439
# id                                                                     0.065511
# (equity - share capital) / total assets                                0.722194
# current_debt_to_total_assets                                           0.321124
# (total liabilities * 365) / (gross profit + dep...                     0.000283
# debt_to_assets                                                         0.518823
# retained_earnings_to_assets                                            1.000000
# net_asset_turnover                                                     0.303233
# constant_capital_to_total_assets                                       0.361454
# asset_turnover                                                         0.123591
# (gross profit + depreciation) / total liabilities                      0.248076
# (net profit + depreciation) / total liabilities                        0.242878
# equity_to_assets                                                       0.541600
# (gross profit + interest) / total assets                               0.383788
# EBIT_to_assets                                                         0.383796
# return_on_assets                                                       0.387198
# Attr22                                                                 0.243028
# working_capital_to_assets                                              0.319003
# asset_to_debt                                                          0.179152
# book_value_equity_to_assets                                            0.184691
# (gross profit + extraordinary items + financial...                     0.295149
# log_assets                                                             0.214415
# current_assets_to_total_debt                                           0.183050
# operating_costs_to_total_debt                                          0.035037
# 3_yr_gross_profitability                                               0.497442
# gross_profit_margin                                                    0.220602
# net_profit_margin                                                      0.192936
# net_profit_ratio                                                       0.217827
# total sales / total assets                                             0.018106
# EBT_to_sales                                                           0.210159
# sales_to_short_term_debt                                               0.066356
# operating_costs_to_current_debt                                        0.066959
# EBITDA_rota                                                            0.213259
# gross_profit_to_current_debt                                           0.053650
# total costs /total sales                                               0.009004
# short_term_quick_ratio                                                 0.010454
# working_capital                                                        0.079924
# EBITDA_sales                                                           0.072610
# current_ratio                                                          0.013914
# gross_profitability                                                    0.074911
# receivables_turnover                                                   0.019480
# (current assets - inventory - receivables) / sh...                     0.006708
# EBITDA_margin                                                          0.073540
# long_term_quick_ratio                                                  0.019149
# inventory_turnover                                                     0.012984
# days_inventory_to_cogs                                                 0.004997
# y/y_sales                                                              0.005999
# days_debt_to_cogs                                                      0.014158
# (gross profit + depreciation) / sales                                  0.001171
# long_term_debt_to_equity                                               0.007804
# [(cash + short-term securities + receivables - ...                     0.001133
# operating_margin                                                       0.001246
# months_debt_to_profit                                                  0.003259
# operating_ratio                                                        0.001699
# contribution_margin                                                    0.001750
# days_sales_in_inventory                                                0.006847
# average_payment_period                                                 0.014642
# rotation_receivables_plus_inventory_turnover                           0.011889
# net_inventory_turnover                                                 0.003519
# days_short_term_debt_to_sales                                          0.035460
# days_receivables_to_sales                                              0.018215
# working_capital_to_fixed_assets                                        0.006138
# constant_capital_to_fixed_assets                                       0.007625
# fixed_asset_turnover                                                   0.012290
# equity_to_fixed_assets                                                 0.075764
# net_debt_to_sales                                                      0.032783
#
#                                                     EBIT_to_assets  \
# class                                                     0.060393
# id                                                        0.015468
# (equity - share capital) / total assets                   0.442089
# current_debt_to_total_assets                              0.309144
# (total liabilities * 365) / (gross profit + dep...        0.004951
# debt_to_assets                                            0.432239
# retained_earnings_to_assets                               0.383796
# net_asset_turnover                                        0.724519
# constant_capital_to_total_assets                          0.392424
# asset_turnover                                            0.162525
# (gross profit + depreciation) / total liabilities         0.580210
# (net profit + depreciation) / total liabilities           0.571875
# equity_to_assets                                          0.499309
# (gross profit + interest) / total assets                  0.999954
# EBIT_to_assets                                            1.000000
# return_on_assets                                          0.989017
# Attr22                                                    0.856139
# working_capital_to_assets                                 0.371232
# asset_to_debt                                             0.176573
# book_value_equity_to_assets                               0.192580
# (gross profit + extraordinary items + financial...        0.941933
# log_assets                                                0.043495
# current_assets_to_total_debt                              0.204708
# operating_costs_to_total_debt                             0.213068
# 3_yr_gross_profitability                                  0.692372
# gross_profit_margin                                       0.455051
# net_profit_margin                                         0.295951
# net_profit_ratio                                          0.440350
# total sales / total assets                                0.216271
# EBT_to_sales                                              0.451172
# sales_to_short_term_debt                                  0.183395
# operating_costs_to_current_debt                           0.153276
# EBITDA_rota                                               0.678952
# gross_profit_to_current_debt                              0.246639
# total costs /total sales                                  0.022310
# short_term_quick_ratio                                    0.070747
# working_capital                                           0.092641
# EBITDA_sales                                              0.149857
# current_ratio                                             0.070875
# gross_profitability                                       0.192486
# receivables_turnover                                      0.039709
# (current assets - inventory - receivables) / sh...        0.051833
# EBITDA_margin                                             0.154421
# long_term_quick_ratio                                     0.006075
# inventory_turnover                                        0.012782
# days_inventory_to_cogs                                    0.007297
# y/y_sales                                                 0.015705
# days_debt_to_cogs                                         0.001238
# (gross profit + depreciation) / sales                     0.006226
# long_term_debt_to_equity                                  0.021983
# [(cash + short-term securities + receivables - ...        0.002953
# operating_margin                                          0.021609
# months_debt_to_profit                                     0.010675
# operating_ratio                                           0.005226
# contribution_margin                                       0.005046
# days_sales_in_inventory                                   0.011992
# average_payment_period                                    0.001660
# rotation_receivables_plus_inventory_turnover              0.012902
# net_inventory_turnover                                    0.020457
# days_short_term_debt_to_sales                             0.035983
# days_receivables_to_sales                                 0.013794
# working_capital_to_fixed_assets                           0.031343
# constant_capital_to_fixed_assets                          0.033267
# fixed_asset_turnover                                      0.010363
# equity_to_fixed_assets                                    0.099330
# net_debt_to_sales                                         0.033689
#
#                                                     book_value_equity_to_assets  \
# class                                                                  0.052561
# id                                                                     0.060273
# (equity - share capital) / total assets                                0.380912
# current_debt_to_total_assets                                           0.436175
# (total liabilities * 365) / (gross profit + dep...                     0.026302
# debt_to_assets                                                         0.508322
# retained_earnings_to_assets                                            0.184691
# net_asset_turnover                                                     0.137764
# constant_capital_to_total_assets                                       0.366766
# asset_turnover                                                         0.091615
# (gross profit + depreciation) / total liabilities                      0.580817
# (net profit + depreciation) / total liabilities                        0.560953
# equity_to_assets                                                       0.466122
# (gross profit + interest) / total assets                               0.192531
# EBIT_to_assets                                                         0.192580
# return_on_assets                                                       0.185841
# Attr22                                                                 0.128558
# working_capital_to_assets                                              0.369517
# asset_to_debt                                                          0.990971
# book_value_equity_to_assets                                            1.000000
# (gross profit + extraordinary items + financial...                     0.156401
# log_assets                                                             0.100488
# current_assets_to_total_debt                                           0.855284
# operating_costs_to_total_debt                                          0.265787
# 3_yr_gross_profitability                                               0.285682
# gross_profit_margin                                                    0.123215
# net_profit_margin                                                      0.090108
# net_profit_ratio                                                       0.113656
# ...
# operating_margin                                                         0.000961
# months_debt_to_profit                                                    0.000618
# operating_ratio                                                          0.956080
# contribution_margin                                                      0.956628
# days_sales_in_inventory                                                  0.956607
# average_payment_period                                                   0.001723
# rotation_receivables_plus_inventory_turnover                             0.982203
# net_inventory_turnover                                                   0.004544
# days_short_term_debt_to_sales                                            1.000000
# days_receivables_to_sales                                                0.992761
# working_capital_to_fixed_assets                                          0.002309
# constant_capital_to_fixed_assets                                         0.002392
# fixed_asset_turnover                                                     0.000393
# equity_to_fixed_assets                                                   0.010363
# net_debt_to_sales                                                        0.975857
#
#                                                     sales_to_short_term_debt  \
# class                                                               0.027075
# id                                                                  0.033985
# (equity - share capital) / total assets                             0.136109
# current_debt_to_total_assets                                        0.239502
# (total liabilities * 365) / (gross profit + dep...                  0.014879
# debt_to_assets                                                      0.194406
# retained_earnings_to_assets                                         0.066356
# net_asset_turnover                                                  0.159593
# constant_capital_to_total_assets                                    0.190635
# asset_turnover                                                      0.158588
# (gross profit + depreciation) / total liabilities                   0.351278
# (net profit + depreciation) / total liabilities                     0.339664
# equity_to_assets                                                    0.176187
# (gross profit + interest) / total assets                            0.183328
# EBIT_to_assets                                                      0.183395
# return_on_assets                                                    0.174946
# Attr22                                                              0.172399
# working_capital_to_assets                                           0.250482
# asset_to_debt                                                       0.277691
# book_value_equity_to_assets                                         0.283566
# (gross profit + extraordinary items + financial...                  0.176370
# log_assets                                                          0.127124
# current_assets_to_total_debt                                        0.310696
# operating_costs_to_total_debt                                       0.383758
# 3_yr_gross_profitability                                            0.191279
# gross_profit_margin                                                 0.069225
# net_profit_margin                                                   0.064392
# net_profit_ratio                                                    0.065648
# total sales / total assets                                          0.202309
# EBT_to_sales                                                        0.061156
# sales_to_short_term_debt                                            1.000000
# operating_costs_to_current_debt                                     0.973265
# EBITDA_rota                                                         0.128417
# gross_profit_to_current_debt                                        0.682109
# total costs /total sales                                            0.008254
# short_term_quick_ratio                                              0.767239
# working_capital                                                     0.033335
# EBITDA_sales                                                        0.016965
# current_ratio                                                       0.781469
# gross_profitability                                                 0.029247
# receivables_turnover                                                0.129986
# (current assets - inventory - receivables) / sh...                  0.655628
# EBITDA_margin                                                       0.035189
# long_term_quick_ratio                                               0.002879
# inventory_turnover                                                  0.001820
# days_inventory_to_cogs                                              0.009554
# y/y_sales                                                           0.008035
# days_debt_to_cogs                                                   0.006222
# (gross profit + depreciation) / sales                               0.007480
# long_term_debt_to_equity                                            0.009697
# [(cash + short-term securities + receivables - ...                  0.003165
# operating_margin                                                    0.023409
# months_debt_to_profit                                               0.001521
# operating_ratio                                                     0.007815
# contribution_margin                                                 0.007805
# days_sales_in_inventory                                             0.012574
# average_payment_period                                              0.006298
# rotation_receivables_plus_inventory_turnover                        0.014422
# net_inventory_turnover                                              0.007570
# days_short_term_debt_to_sales                                       0.027233
# days_receivables_to_sales                                           0.016505
# working_capital_to_fixed_assets                                     0.047127
# constant_capital_to_fixed_assets                                    0.048171
# fixed_asset_turnover                                                0.003102
# equity_to_fixed_assets                                              0.113167
# net_debt_to_sales                                                   0.023269
#
#                                                     fixed_asset_turnover  \
# class                                                           0.000729
# id                                                              0.015933
# (equity - share capital) / total assets                         0.020326
# current_debt_to_total_assets                                    0.045195
# (total liabilities * 365) / (gross profit + dep...              0.000523
# debt_to_assets                                                  0.029751
# retained_earnings_to_assets                                     0.012290
# net_asset_turnover                                              0.008601
# constant_capital_to_total_assets                                0.033423
# asset_turnover                                                  0.022930
# (gross profit + depreciation) / total liabilities               0.005845
# (net profit + depreciation) / total liabilities                 0.006293
# equity_to_assets                                                0.025689
# (gross profit + interest) / total assets                        0.010357
# EBIT_to_assets                                                  0.010363
# return_on_assets                                                0.009089
# Attr22                                                          0.010886
# working_capital_to_assets                                       0.017464
# asset_to_debt                                                   0.014471
# book_value_equity_to_assets                                     0.014360
# (gross profit + extraordinary items + financial...              0.012624
# log_assets                                                      0.032100
# current_assets_to_total_debt                                    0.003667
# operating_costs_to_total_debt                                   0.009805
# 3_yr_gross_profitability                                        0.002656
# gross_profit_margin                                             0.006534
# net_profit_margin                                               0.005624
# net_profit_ratio                                                0.006090
# total sales / total assets                                      0.021781
# EBT_to_sales                                                    0.005933
# sales_to_short_term_debt                                        0.003102
# operating_costs_to_current_debt                                 0.001439
# EBITDA_rota                                                     0.015519
# gross_profit_to_current_debt                                    0.008154
# total costs /total sales                                        0.003313
# short_term_quick_ratio                                          0.008744
# working_capital                                                 0.002655
# EBITDA_sales                                                    0.001890
# current_ratio                                                   0.007878
# gross_profitability                                             0.001441
# receivables_turnover                                            0.005590
# (current assets - inventory - receivables) / sh...              0.008050
# EBITDA_margin                                                   0.004897
# long_term_quick_ratio                                           0.000665
# inventory_turnover                                              0.000373
# days_inventory_to_cogs                                          0.000611
# y/y_sales                                                       0.000740
# days_debt_to_cogs                                               0.002198
# (gross profit + depreciation) / sales                           0.000648
# long_term_debt_to_equity                                        0.000711
# [(cash + short-term securities + receivables - ...              0.000091
# operating_margin                                                0.000540
# months_debt_to_profit                                           0.000516
# operating_ratio                                                 0.000660
# contribution_margin                                             0.000659
# days_sales_in_inventory                                         0.001203
# average_payment_period                                          0.002191
# rotation_receivables_plus_inventory_turnover                    0.000483
# net_inventory_turnover                                          0.000651
# days_short_term_debt_to_sales                                   0.000393
# days_receivables_to_sales                                       0.002681
# working_capital_to_fixed_assets                                 0.980430
# constant_capital_to_fixed_assets                                0.977975
# fixed_asset_turnover                                            1.000000
# equity_to_fixed_assets                                          0.485156
# net_debt_to_sales                                               0.000842
#
#                                                        class
# class                                               1.000000
# id                                                  0.248492
# (equity - share capital) / total assets             0.108345
# current_debt_to_total_assets                        0.088557
# (total liabilities * 365) / (gross profit + dep...  0.087065
# debt_to_assets                                      0.080942
# retained_earnings_to_assets                         0.080439
# net_asset_turnover                                  0.076142
# constant_capital_to_total_assets                    0.072470
# asset_turnover                                      0.069774
# (gross profit + depreciation) / total liabilities   0.067855
# (net profit + depreciation) / total liabilities     0.067217
# equity_to_assets                                    0.065548
# (gross profit + interest) / total assets            0.060415
# EBIT_to_assets                                      0.060393
# return_on_assets                                    0.058435
# Attr22                                              0.058017
# working_capital_to_assets                           0.054505
# asset_to_debt                                       0.054061
# book_value_equity_to_assets                         0.052561
# (gross profit + extraordinary items + financial...  0.047881
# log_assets                                          0.047720
# current_assets_to_total_debt                        0.042385
# operating_costs_to_total_debt                       0.038991
# 3_yr_gross_profitability                            0.037652
# gross_profit_margin                                 0.036669
# net_profit_margin                                   0.036123
# net_profit_ratio                                    0.033845
# total sales / total assets                          0.029666
# EBT_to_sales                                        0.029006
# sales_to_short_term_debt                            0.027075
# operating_costs_to_current_debt                     0.023707
# EBITDA_rota                                         0.023647
# gross_profit_to_current_debt                        0.019925
# total costs /total sales                            0.017096
# short_term_quick_ratio                              0.016708
# working_capital                                     0.016395
# EBITDA_sales                                        0.016100
# current_ratio                                       0.015788
# gross_profitability                                 0.014192
# receivables_turnover                                0.011771
# (current assets - inventory - receivables) / sh...  0.010834
# EBITDA_margin                                       0.004931
# long_term_quick_ratio                               0.004524
# inventory_turnover                                  0.004438
# days_inventory_to_cogs                              0.003314
# y/y_sales                                           0.002504
# days_debt_to_cogs                                   0.002485
# (gross profit + depreciation) / sales               0.002366
# long_term_debt_to_equity                            0.002278
# [(cash + short-term securities + receivables - ...  0.002236
# operating_margin                                    0.002226
# months_debt_to_profit                               0.002169
# operating_ratio                                     0.002157
# contribution_margin                                 0.002151
# days_sales_in_inventory                             0.002005
# average_payment_period                              0.001982
# rotation_receivables_plus_inventory_turnover        0.001802
# net_inventory_turnover                              0.001741
# days_short_term_debt_to_sales                       0.001531
# days_receivables_to_sales                           0.001493
# working_capital_to_fixed_assets                     0.001099
# constant_capital_to_fixed_assets                    0.001072
# fixed_asset_turnover                                0.000729
# equity_to_fixed_assets                              0.000727
# net_debt_to_sales                                   0.000357

# %% [markdown]
# By both comparing graphs of features against target and the correlation matrix, features '(equity - share capital) / total assets', 'current_debt_to_total_assets', and '(total liabilities * 365) / (gross profit + depreciation)' seem to be most influential in terms of determining whether or not a company goes bankrupt in 3 years' time. To weight these features more heavily, new columns are made in the dataframe. These three new columns are the square product of each one of those influential features, respectively, to more heavily weight their effect on the target variable.

# %%
# Create new features of the squares of the top three most influential features to weight more heavily

df['(equity - share capital) / total assets SQUARE']=df['(equity - share capital) / total assets'].map(lambda x: x**2)
df['current_debt_to_total_assets SQUARE']=df['current_debt_to_total_assets'].map(lambda x: x**2)
df['(total liabilities * 365) / (gross profit + depreciation) SQUARE']=df['(total liabilities * 365) / (gross profit + depreciation)'].map(lambda x: x**2)

# %% [markdown]
# Distributions for these new, engineered features are then plotted for visual inspection below. As can be seen, the absolute value ranges (since negative numbers squared become positive) for both bankrupt and non-bankrupt company sets for each respective feature increase. This allows for added weighting of importance for each of the three engineered features, as well as gauging of these features based on magnitude and absolute value, since any negative numbers squared become positive.

# %%
# Establish graph figure

fig=plt.figure(figsize=[20, 20])

# Graph each of the 7 important features and set labels and titles

ax1 = fig.add_subplot(241)
g = sns.violinplot(x="class", y="(equity - share capital) / total assets SQUARE", data=df, ax=ax1)
ax1.set_title('Square of Equity over Assets vs. Bankruptcy', fontsize=8);
ax1.set_ylabel('Square of Equity over Assets', fontsize=8);
ax1.set_xlabel('Bankruptcy', fontsize=8);

ax2 = fig.add_subplot(242)
g = sns.violinplot(x="class", y="current_debt_to_total_assets SQUARE", data=df, ax=ax2)
ax2.set_title('Square of Debt to Assets vs. Bankruptcy', fontsize=8);
ax2.set_ylabel('Square of Debt to Assets', fontsize=8);
ax2.set_xlabel('Bankruptcy', fontsize=8);

ax3 = fig.add_subplot(243)
g = sns.violinplot(x="class", y="(total liabilities * 365) / (gross profit + depreciation) SQUARE", data=df, ax=ax3)
ax3.set_title('Square of Liabilities over Profit vs. Bankruptcy', fontsize=8);
ax3.set_ylabel('Square of Liabilities over Profit', fontsize=8);
ax3.set_xlabel('Bankruptcy', fontsize=8);

# %% [markdown]
# # Model Fitting and Interpretation

# %% [markdown]
# With the prepped data set, the data science team proceeds to create models that represent the data. The team first splits the data into training and testing sets in order to prevent overfitting of the models to the data. The team then creates models of many different types (KNN, Logistic Regression, Decision Tree, and Random Forest) in order to see which variety of model best fits to the data. After evaluating each model type on its own, the team combines these models into an ensemble to ultimately maximize integrity of the overall model. Since the percentage of bankruptcies is very low in the data set and since both false negatives and false positives are potentially harmful and costly in the context of taking bullish or bearish positions on a company, the team uses F1-score as the main metric by which the quality of models is evaluated. The team uses precision as a secondary metric, just because in general, it would probably be more harmful to make extreme financial decisions about a company that is expected to go bankrupt when, in reality, it doesn't. Accuracy is also used by the team to judge models, but mainly just as a reference.

# %% [markdown]
# ## Train-test Split

# %% [markdown]
# As mentioned, the data is first split into train and test sets to prevent model overfitting. This split is done below and used for all developed models.

# %%
# Establish features and target in data

X=df.drop(['class'], axis=1)
y=df['class']

# Split features and target into training and testing partitions

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# Scale feature set according to standard distribution to make results more interpretable
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)  
X_test = scaler.transform(X_test)

# %% [markdown]
# ## KNN Model

# %% [markdown]
# A simple KNN model is first produced. GridSearchCV is used in order to tune for optimal hyperparameters. Those parameters are then used in the model, and a corresponding F-1 score is produced. Precision is used as a secondary metric by which to gauge the model. Accuracy is used as a tertiary gauge of the model, although it is not focused upon, as the data set's class imbalance confounds the meaning of that metric.

# %%
# KNN parameters are set up to be evaluated

param_grid = { 
    'n_neighbors': list(range(1,50)),
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
    }

# Grid search is executed with F1 as scoring method

grid_knn=GridSearchCV(KNeighborsClassifier(), param_grid, cv=5, scoring='f1', verbose=1, n_jobs=-1)

# KNN model is fit to data set and optimal parameters are found

grid_knn.fit(X_train, y_train)
grid_knn.best_params_

# %% [markdown]
# The resultant parameters are then used in a KNN model, which is fit to training data and then measured against the test set.

# %%
# Establish KNN model

knn=KNeighborsClassifier(metric='manhattan', n_neighbors=1, weights='uniform')

# Fit KNN model to training data

knn.fit(X_train, y_train)

# Make predictions on test set with model

knn_preds = knn.predict(X_test)

# Evaluate KNN model based on F1-score, and display accuracy just for reference

knn_f1 = metrics.f1_score(y_test, knn_preds)
knn_acc = metrics.accuracy_score(y_test, knn_preds)
knn_pre = metrics.precision_score(y_test, knn_preds)

print(knn_f1, knn_acc, knn_pre)
# Out:
# 0.14285714285714285 0.9705400981996727 0.2

# %% [markdown]
# As can be seen, the model has an F-1 score of ~0.14, which is not great. The precision is 0.2, which is also not great. Accuracy is above 0.97, which is good, but this is likely due to the class imbalance of the target in the set.

# %% [markdown]
# ## Logistic Regression Model

# %% [markdown]
# A logistic regression model is next produced. GridSearchCV is used in order to tune for optimal hyperparameters. Those parameters are then used in the model, and a corresponding F-1 score is produced. Precision is used as a secondary metric by which to gauge the model. Accuracy is used as a tertiary gauge of the model, although it is not focused upon, as the data set's class imbalance confounds the meaning of that metric.

# %%
# Logistic regression parameters are set up to be evaluated

param_grid = { 
    'C': list(range(1,25)),
    'penalty': ['l1', 'l2'],
    'class_weight': ['balanced', None]
    }

# Grid search is executed with F1 as scoring method

grid_lr=GridSearchCV(LogisticRegression(random_state=1), param_grid, cv=5, scoring='f1', verbose=1, n_jobs=-1)

# Logistic regression model is fit to data set and optimal parameters are found

grid_lr.fit(X_train, y_train)

grid_lr.best_params_

# %% [markdown]
# The resultant parameters are then used in a logistic regression model, which is fit to training data and then measured against the test set.

# %%
# Establish logistic regression model

lr = LogisticRegression(class_weight=None, C=22, penalty='l1', random_state=1)

# Fit logistic regression model to training data

lr.fit(X_train, y_train)

# Make predictions on test set with model

lr_preds = lr.predict(X_test)

# Evaluate logistic regression model based on F1-score, and display accuracy just for reference

lr_f1 = metrics.f1_score(y_test, lr_preds)
lr_acc = metrics.accuracy_score(y_test, lr_preds)
lr_pre = metrics.precision_score(y_test, lr_preds)

print(lr_f1, lr_acc, lr_pre)
# Out:
# 0.8928571428571429 0.9950900163666121 0.8620689655172413

# %% [markdown]
# As can be seen, the model has an F-1 score of ~0.89, which is pretty high, indicating high integrity of the model. Precision is ~0.86, which is also high and indicates low likelihood of predicting false positives. Accuracy is above 0.99, which is good, but this is likely due to the class imbalance of the target in the set.

# %% [markdown]
# ## Decision Tree Model

# %% [markdown]
# A decision tree model is next produced. GridSearchCV is used in order to tune for optimal hyperparameters. Those parameters are then used in the model, and a corresponding F-1 score is produced. Precision is used as a secondary metric by which to gauge the model. Accuracy is used as a tertiary gauge of the model, although it is not focused upon, as the data set's class imbalance confounds the meaning of that metric.

# %%
# Decision tree parameters are set up to be evaluated

param_grid = { 
    'criterion': ['gini', 'entropy'],
    'max_depth': list(range(1,20)),
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [2, 5, 10],
    'min_weight_fraction_leaf': [0, 0.25, 0.5],
    'max_features': ['auto', 'sqrt', 'log2'],
    'min_impurity_decrease': [0, 0.4, 0.8],
    'min_impurity_split': [0, 0.4, 0.8]
    }

# Grid search is executed with F1 as scoring method

grid_dt=GridSearchCV(DecisionTreeClassifier(class_weight='balanced', random_state=1), param_grid, cv=5, scoring='f1', verbose=1, n_jobs=-1)

# Decision tree model is fit to data set and optimal parameters are found

grid_dt.fit(X_train, y_train)

grid_dt.best_params_

# %% [markdown]
# The resultant parameters are then used in a decision tree model, which is fit to training data and then measured against the test set.

# %%
# Establish decision tree model

dtc = DecisionTreeClassifier(criterion= 'entropy',
 max_depth= 18,
 max_features= 'log2',
 min_impurity_decrease= 0,
 min_impurity_split= 0,
 min_samples_leaf= 2,
 min_samples_split= 5,
 min_weight_fraction_leaf= 0,
 random_state=1,
 class_weight='balanced')

# Fit decision tree model to training data

dtc.fit(X_train, y_train)

# Make predictions on test set with model

dtc_preds  = dtc.predict(X_test)

# Evaluate decision tree model based on F1-score, and display accuracy just for reference

dtc_f1 = metrics.f1_score(y_test, dtc_preds)
dtc_acc = metrics.accuracy_score(y_test, dtc_preds)
dtc_pre = metrics.precision_score(y_test, dtc_preds)

print(dtc_f1, dtc_acc, dtc_pre)
# Out:
# 0.9019607843137256 0.9959083469721768 0.9583333333333334

# %% [markdown]
# As can be seen, the model has an F-1 score of ~0.9, which is pretty high, indicating high integrity of the model. Precision is ~0.96, which is also high and indicates low likelihood of predicting false positives. Accuracy is above 0.99, which is good, but this is likely due to the class imbalance of the target in the set.

# %% [markdown]
# ## Random Forest Model

# %% [markdown]
# A random forest model is next produced. GridSearchCV is used in order to tune for optimal hyperparameters. Those parameters are then used in the model, and a corresponding F-1 score is produced. Precision is used as a secondary metric by which to gauge the model. Accuracy is used as a tertiary gauge of the model, although it is not focused upon, as the data set's class imbalance confounds the meaning of that metric.

# %%
# Random forest parameters are set up to be evaluated

param_grid = { 
    'criterion': ['gini', 'entropy'],
    'max_depth': list(range(1,20)),
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [2, 5, 10],
    'min_weight_fraction_leaf': [0, 0.25, 0.5],
    'max_features': ['auto', 'sqrt', 'log2'],
    'min_impurity_decrease': [0, 0.4, 0.8],
    'min_impurity_split': [0, 0.4, 0.8],
    'bootstrap': [True, False]
    }

# Grid search is executed with F1 as scoring method

grid_tree=GridSearchCV(RandomForestClassifier(random_state=1), param_grid, cv=5, scoring='f1', verbose=1, n_jobs=-1)

# Decision tree model is fit to data set and optimal parameters are found

grid_tree.fit(X_train, y_train)
grid_tree.best_params_

# %% [markdown]
# The resultant parameters are then used in a random forrest model, which is fit to training data and then measured against the test set.

# %%
# Establish random forest model

rfc = RandomForestClassifier(bootstrap=False, class_weight='balanced',
                                              criterion='gini', max_depth=11,
                                              max_features='auto',
                                              min_impurity_decrease=0.0,
                                              min_impurity_split=0,
                                              min_samples_leaf=2,
                                              min_samples_split=10,
                                              min_weight_fraction_leaf=0,
                                              random_state=1)

# Fit random forest model to training data

rfc.fit(X_train, y_train)

# Make predictions on test set with model

rfc_preds  = rfc.predict(X_test)

# Evaluate decision tree model based on F1-score and precision, and display accuracy just for reference

rfc_f1 = metrics.f1_score(y_test, rfc_preds)
rfc_acc = metrics.accuracy_score(y_test, rfc_preds)
rfc_pre = metrics.precision_score(y_test, rfc_preds)

print(rfc_f1, rfc_acc, rfc_pre)
# Out:
# 0.8260869565217391 0.9934533551554828 1.0

# %% [markdown]
# As can be seen, the model has an F-1 score of ~0.83, which is pretty high, indicating high integrity of the model. Precision is 1.0, which means no false positives were predicted at all. Accuracy is above 0.99, which is good, but this is likely due to the class imbalance of the target in the set.

# %% [markdown]
# ## Combination into Ensemble Model

# %% [markdown]
# The different models are then combined into ensembles to see which combinations yield the highest F-1 score, when gauged against the test set. Since the reliability of the KNN model was very low, that model is excluded from this analysis. Every possible combination of the logistic regression, decision tree, and random forest model was weighed against one another to find the one with the highest integrity.

# %%
# Create ensemble models for each combination of the accepted three models

voting_clf1 = VotingClassifier(
                estimators=[('logreg', lr), ('decisiontree', dtc), ('randomforest', rfc)], 
                voting='soft')

voting_clf2 = VotingClassifier(
                estimators=[('logreg', lr), ('decisiontree', dtc)], 
                voting='soft')

voting_clf3 = VotingClassifier(
                estimators=[('logreg', lr), ('randomforest', rfc)], 
                voting='soft')

voting_clf4 = VotingClassifier(
                estimators=[('decisiontree', dtc), ('randomforest', rfc)], 
                voting='soft')

# Fit each model to the training data

voting_clf1.fit(X_train, y_train)
voting_clf2.fit(X_train, y_train)
voting_clf3.fit(X_train, y_train)
voting_clf4.fit(X_train, y_train)

# Create bankruptcy predictions with each model

vc_preds1 = voting_clf1.predict(X_test)
vc_preds2 = voting_clf2.predict(X_test)
vc_preds3 = voting_clf3.predict(X_test)
vc_preds4 = voting_clf4.predict(X_test)

# Evaluate each model based on F1-score, and display accuracy just for reference

vc_f1_1 = metrics.f1_score(y_test, vc_preds1)
vc_acc_1 = metrics.accuracy_score(y_test, vc_preds1)
vc_pre_1 = metrics.precision_score(y_test, vc_preds1)

vc_f1_2 = metrics.f1_score(y_test, vc_preds2)
vc_acc_2 = metrics.accuracy_score(y_test, vc_preds2)
vc_pre_2 = metrics.precision_score(y_test, vc_preds2)

vc_f1_3 = metrics.f1_score(y_test, vc_preds3)
vc_acc_3 = metrics.accuracy_score(y_test, vc_preds3)
vc_pre_3 = metrics.precision_score(y_test, vc_preds3)

vc_f1_4 = metrics.f1_score(y_test, vc_preds4)
vc_acc_4 = metrics.accuracy_score(y_test, vc_preds4)
vc_pre_4 = metrics.precision_score(y_test, vc_preds4)

print(vc_f1_1, vc_acc_1, vc_pre_1)
print(vc_f1_2, vc_acc_2, vc_pre_2)
print(vc_f1_3, vc_acc_3, vc_pre_3)
print(vc_f1_4, vc_acc_4, vc_pre_4)
# Out:
# 0.9411764705882353 0.997545008183306 1.0
# 0.8979591836734693 0.9959083469721768 1.0
# 0.9433962264150944 0.997545008183306 0.9615384615384616
# 0.92 0.9967266775777414 1.0

# %% [markdown]
# As can be seen, the highest F-1 score was produced by the ensemble of the logistic regression and random forest models. This score was over 0.94, which indicates very high integrity of the model. Second highest F-1 score was produced by the ensemble of all models, which was also above 0.94. In terms of precision, though, the ensemble of all models performs better than the combination of the logistic regression and random forest. Accuracy is high for all models. Overall, then, the team deems the ensemble of all logistic regression, decision tree, and random forest models as being the best model, as it maximizes both the F-1 score and precision.

# %% [markdown]
# ## Resulting Feature Analysis

# %% [markdown]
# With a high-integrity model having been created, the team then analyzes which features were most influential for each model. This info gives consumers of the model a general gauge of important metrics to look into when evaluating whether or not a company is expected to go bankrupt.
#
# The first model evaluated is the linear regression model.

# %%
# Find most important features in random forest model

lr_importances_orig=list(lr.coef_[0])
lr_importances=list(lr.coef_[0])
lr_importances=[abs(ele) for ele in lr_importances]


# Sort the list

index=list(range(0, len(lr_importances)))
lr_importances.sort()

# Find indeces and names of features with highest magnitude influence

imp1=lr_importances[-2]
imp2=lr_importances[-3]
imp3=lr_importances[-4]

ind1=None
ind2=None
ind3=None

for num in index:
    if lr_importances_orig[num]==imp1 or lr_importances_orig[num]==-1*imp1:
        ind1=num
    if lr_importances_orig[num]==imp2 or lr_importances_orig[num]==-1*imp2:
        ind2=num
    if lr_importances_orig[num]==imp3 or lr_importances_orig[num]==-1*imp3:
        ind3=num

# Display most influential features        

print(df.columns[ind1])
print(df.columns[ind2])
print(df.columns[ind3])
# Out:
# (gross profit + depreciation) / total liabilities
# book_value_equity_to_assets
# current_assets_to_total_debt

# %% [markdown]
# As can be gleaned from results of the analysis, the top three most impactful features for the logistic regression model were, in order, '(gross profit + depreciation) / total liabilities', 'book_value_equity_to_assets', and 'current_assets_to_total_debt'.
#
# Features of the decision tree model are then examined to find which features are most influential for this model.

# %%
# Find most important features in decision tree model

dtc_importances_orig=list(dtc.feature_importances_) 
dtc_importances=list(dtc.feature_importances_)
dtc_importances=[abs(ele) for ele in dtc_importances]


# Sort the list

index=list(range(0, len(dtc_importances)))
dtc_importances.sort()

# Find indeces and names of features with highest magnitude influence

imp1=dtc_importances[-2]
imp2=dtc_importances[-3]
imp3=dtc_importances[-4]

ind1=None
ind2=None
ind3=None

for num in index:
    if dtc_importances_orig[num]==imp1:
        ind1=num
    if dtc_importances_orig[num]==imp2:
        ind2=num
    if dtc_importances_orig[num]==imp3:
        ind3=num

# Display most influential features        

print(df.columns[ind1])
print(df.columns[ind2])
print(df.columns[ind3])
# Out:
# operating_costs_to_total_debt
# current_debt_to_total_assets SQUARE
# (gross profit + depreciation) / total liabilities

# %% [markdown]
# As can be gleaned from results of the analysis, the top three most impactful features for the decision tree model were, in order, 'operating_costs_to_total_debt', 'current_debt_to_total_assets SQUARE', and '(gross profit + depreciation) / total liabilities'.
#
# Features of the random forest model are then examined to find which features are most influential for this model.

# %%
# Find most important features in random forest model

rfc_importances_orig=list(rfc.feature_importances_) 
rfc_importances=list(rfc.feature_importances_)
rfc_importances=[abs(ele) for ele in rfc_importances]


# Sort the list

index=list(range(0, len(rfc_importances)))
rfc_importances.sort()

# Find indeces and names of features with highest magnitude influence

imp1=rfc_importances[-2]
imp2=rfc_importances[-3]
imp3=rfc_importances[-4]

ind1=None
ind2=None
ind3=None

for num in index:
    if rfc_importances_orig[num]==imp1:
        ind1=num
    if rfc_importances_orig[num]==imp2:
        ind2=num
    if rfc_importances_orig[num]==imp3:
        ind3=num

# Display most influential features        

print(df.columns[ind1])
print(df.columns[ind2])
print(df.columns[ind3])
# Out:
# operating_costs_to_total_debt
# retained_earnings_to_assets
# (gross profit + depreciation) / sales

# %% [markdown]
# As can be gleaned from results of the analysis, the top three most impactful features for the random forest model were, in order, 'operating_costs_to_total_debt', 'retained_earnings_to_assets', and '(gross profit + depreciation) / sales'.
#
# Across all models, then, most important features can be seen below:
# - (gross profit + depreciation) / total liabilities
# - book_value_equity_to_assets
# - current_assets_to_total_debt
# - operating_costs_to_total_debt
# - current_debt_to_total_assets SQUARE
# - retained_earnings_to_assets
# - (gross profit + depreciation) / sales
#
# As someone evaluating the likelihood of a company's impending bankruptcy without this model, then, commonalities between these features should be assessed. These commonalities would be, generally, current and total assets, current and total debt, operating costs, earnings, and profit. The general distributions of these features can be seen below in violin plots.

# %%
# Establish graph figure

fig=plt.figure(figsize=[20, 20])

# Graph each of the 7 important features and set labels and titles

ax1 = fig.add_subplot(241)
g = sns.violinplot(x="class", y="(gross profit + depreciation) / total liabilities", data=df, ax=ax1)
ax1.set_title('Profit over Liabilities vs. Bankruptcy', fontsize=10);
ax1.set_ylabel('Profit over Liabilities', fontsize=10);
ax1.set_xlabel('Bankruptcy', fontsize=10);

ax2 = fig.add_subplot(242)
g = sns.violinplot(x="class", y="book_value_equity_to_assets", data=df, ax=ax2)
ax2.set_title('Equity to Assets vs. Bankruptcy', fontsize=10);
ax2.set_ylabel('Equity to Assets', fontsize=10);
ax2.set_xlabel('Bankruptcy', fontsize=10);

ax3 = fig.add_subplot(243)
g = sns.violinplot(x="class", y="current_assets_to_total_debt", data=df, ax=ax3)
ax3.set_title('Assets to Debt vs. Bankruptcy', fontsize=10);
ax3.set_ylabel('Assets to Debt', fontsize=10);
ax3.set_xlabel('Bankruptcy', fontsize=10);

ax4 = fig.add_subplot(244)
g = sns.violinplot(x="class", y="operating_costs_to_total_debt", data=df, ax=ax4)
ax4.set_title('Operating Cost to Debt vs. Bankruptcy', fontsize=10);
ax4.set_ylabel('Operating Cost to Debt', fontsize=10);
ax4.set_xlabel('Bankruptcy', fontsize=10);

ax5 = fig.add_subplot(245)
g = sns.violinplot(x="class", y="current_debt_to_total_assets SQUARE", data=df, ax=ax5)
ax5.set_title('Square of Debt to Assets vs. Bankruptcy', fontsize=10);
ax5.set_ylabel('Square of Debt to Assets', fontsize=10);
ax5.set_xlabel('Bankruptcy', fontsize=10);

ax6 = fig.add_subplot(246)
g = sns.violinplot(x="class", y="retained_earnings_to_assets", data=df, ax=ax6)
ax6.set_title('Earnings to Assets vs. Bankruptcy', fontsize=10);
ax6.set_ylabel('Earnings to Assets', fontsize=10);
ax6.set_xlabel('Bankruptcy', fontsize=10);

ax7 = fig.add_subplot(247)
g = sns.violinplot(x="class", y="(gross profit + depreciation) / sales", data=df, ax=ax7)
ax7.set_title('Profit over Sales vs. Bankruptcy', fontsize=10);
ax7.set_ylabel('Profit over Sales', fontsize=10);
ax7.set_xlabel('Bankruptcy', fontsize=10);

# %% [markdown]
# In general, feature value ranges for companies that did not go bankrupt are much larger than those of companies that did go bankrupt, which makes sense. Smaller ranges for those companies indicate "dead zones" for those features, which are essentially ranges that companies should avoid if they're trying to avoid bankruptcy.

# %% [markdown]
# # Conclusion and Next Steps

# %% [markdown]
# Overall, the most highly performing model was the ensemble model that combined logistic regression, decision tree, and random forest models. This ensemble model produced an F1-score of ~0.94 and a perfect precision (no false positives were predicted).
#
# Most important features to this model are as follows:
# - (gross profit + depreciation) / total liabilities
# - book_value_equity_to_assets
# - current_assets_to_total_debt
# - operating_costs_to_total_debt
# - current_debt_to_total_assets SQUARE
# - retained_earnings_to_assets
# - (gross profit + depreciation) / sales
#
# Based on these feature importances, leverage and liquidity appear to be the most indicative of a company’s financial health. Of the top seven most important features in our final ensemble, three were leverage-oriented and two were liquidity-oriented ratios. The remaining two were activity-oriented and profitability-oriented ratios. Based on our analysis, for Polish companies over the period 2000-2013, the more leverage (debt) a company used and the less liquid its assets were, the more likely it was to go bankrupt. Therefore, without the use of a model, one should look into a company's leverage and liquidity when gauging whether or not that company is likely to go bankrupt.
#
# Whereas this dataset only included a small subset of global companies, the data science team believes more relevant analysis (i.e. one that includes more global companies as opposed to just Polish ones) would prove much more useful. One obstacle preventing this is the dearth of relevant data (i.e. recent data on U.S. bankruptcies). This data is difficult to collect and cannot be done with a simple web scraping script, as it's controlled by a handful of research firms that charge for its access. In the future, the team would like to apply the developed models to current U.S. companies to test its performance. In that way, the validity of the model could truly be tested, and it could be confidently used to predict the bankruptcy of companies outside of Poland.
